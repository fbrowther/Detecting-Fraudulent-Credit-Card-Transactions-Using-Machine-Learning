# %%
# Import our dependencies
# %matplotlib inline
import numpy as np
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import sklearn as skl
import pandas as pd
import tensorflow as tf
import h5py

# %%
df = pd.read_csv("creditcardfraud_normalised.csv")
df
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 0      0.935192  0.766490  0.881365  0.313023  0.763439  0.267669  0.266815
# 1      0.978542  0.770067  0.840298  0.271796  0.766120  0.262192  0.264875
# 2      0.935217  0.753118  0.868141  0.268766  0.762329  0.281122  0.270177
# 3      0.941878  0.765304  0.868484  0.213661  0.765647  0.275559  0.266803
# 4      0.938617  0.776520  0.864251  0.269796  0.762975  0.263984  0.268968
# ...         ...       ...       ...       ...       ...       ...       ...
# 24243  0.948840  0.776617  0.871599  0.267317  0.763425  0.255198  0.269028
# 24244  0.980548  0.767956  0.830221  0.247211  0.766713  0.255894  0.267392
# 24245  0.957812  0.772147  0.842697  0.270373  0.770015  0.274533  0.264890
# 24246  0.979492  0.774957  0.833168  0.350926  0.771441  0.264183  0.268462
# 24247  0.977365  0.754947  0.854719  0.231581  0.700000       NaN       NaN
#
#              V8        V9       V10  ...       V21       V22       V23  \
# 0      0.786444  0.475312  0.510600  ...  0.561184  0.522992  0.663793
# 1      0.786298  0.453981  0.505267  ...  0.557840  0.480237  0.666938
# 2      0.788042  0.410603  0.513018  ...  0.565477  0.546030  0.678939
# 3      0.789434  0.414999  0.507585  ...  0.559734  0.510277  0.662607
# 4      0.782484  0.490950  0.524303  ...  0.561327  0.547271  0.663392
# ...         ...       ...       ...  ...       ...       ...       ...
# 24243  0.783901  0.460085  0.496685  ...  0.562676  0.529338  0.662687
# 24244  0.782005  0.461058  0.505840  ...  0.559592  0.493395  0.662612
# 24245  0.792736  0.485243  0.489372  ...  0.561028  0.526264  0.668086
# 24246  0.784047  0.425234  0.522741  ...  0.560892  0.507532  0.662688
# 24247       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28    Amount  class
# 0      0.391253  0.585122  0.394557  0.418976  0.312697  0.005824    0.0
# 1      0.336440  0.587290  0.446013  0.416345  0.313423  0.000105    0.0
# 2      0.289354  0.559515  0.402727  0.415489  0.311911  0.014739    0.0
# 3      0.223826  0.614245  0.389197  0.417669  0.314371  0.004807    0.0
# 4      0.401270  0.566343  0.507497  0.420561  0.317490  0.002724    0.0
# ...         ...       ...       ...       ...       ...       ...    ...
# 24243  0.516260  0.571490  0.478333  0.415855  0.315740  0.000039    0.0
# 24244  0.317336  0.609851  0.599011  0.414577  0.313004  0.001607    0.0
# 24245  0.238670  0.542020  0.494071  0.421828  0.313180  0.000479    0.0
# 24246  0.280936  0.622205  0.449730  0.416138  0.313107  0.000074    0.0
# 24247       NaN       NaN       NaN       NaN       NaN       NaN    NaN
#
# [24248 rows x 30 columns]

# %%
# Remove class target from features data
y = df["class"].values
X = df.drop(columns="class").values

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
number_input_features = len(X_train[0])

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=number_input_features))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                480
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 769
# Trainable params: 769
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 569/569 [==============================] - 2s 1ms/step - loss: 0.0378 - accuracy: 0.9966
# Epoch 2/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0166 - accuracy: 0.9966
# Epoch 3/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0118 - accuracy: 0.9969
# Epoch 4/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0095 - accuracy: 0.9974
# Epoch 5/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0087 - accuracy: 0.9976
# Epoch 6/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0084 - accuracy: 0.9975
# Epoch 7/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0083 - accuracy: 0.9976
# Epoch 8/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0078 - accuracy: 0.9976
# Epoch 9/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0076 - accuracy: 0.9977
# Epoch 10/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0075 - accuracy: 0.9977
# Epoch 11/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 12/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0068 - accuracy: 0.9980
# Epoch 13/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0066 - accuracy: 0.9980
# Epoch 14/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0062 - accuracy: 0.9979
# Epoch 15/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0059 - accuracy: 0.9980
# Epoch 16/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0057 - accuracy: 0.9981
# Epoch 17/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0057 - accuracy: 0.9979
# Epoch 18/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0053 - accuracy: 0.9979
# Epoch 19/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0052 - accuracy: 0.9981
# Epoch 20/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0053 - accuracy: 0.9980
# Epoch 21/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0052 - accuracy: 0.9981
# Epoch 22/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0050 - accuracy: 0.9982
# Epoch 23/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0049 - accuracy: 0.9980
# Epoch 24/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0053 - accuracy: 0.9981
# Epoch 25/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0050 - accuracy: 0.9983
# Epoch 26/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0048 - accuracy: 0.9983
# Epoch 27/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0046 - accuracy: 0.9982
# Epoch 28/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0046 - accuracy: 0.9983
# Epoch 29/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0047 - accuracy: 0.9982
# Epoch 30/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0044 - accuracy: 0.9984
# Epoch 31/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 32/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0045 - accuracy: 0.9982
# Epoch 33/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0047 - accuracy: 0.9984
# Epoch 34/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 35/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9982
# Epoch 36/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9984
# Epoch 37/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 38/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0041 - accuracy: 0.9985
# Epoch 39/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 40/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 41/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 42/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 43/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 44/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 45/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 46/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 47/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 48/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 49/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9989
# Epoch 50/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 51/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 52/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 53/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 54/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 55/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 56/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 57/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 58/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 59/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 60/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 61/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 62/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 63/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 64/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 65/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 66/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 67/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 68/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 69/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 70/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 71/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 72/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 73/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 74/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 75/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 76/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 77/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 78/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 79/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 80/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 81/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 82/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 83/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 84/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 85/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 86/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 87/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 88/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 89/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 90/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 91/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 92/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 93/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0033 - accuracy: 0.9991
# Epoch 94/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 95/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 96/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 97/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 98/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 99/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 100/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.0028 - accuracy: 0.9992

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 190/190 - 0s - loss: nan - accuracy: 0.9987 - 313ms/epoch - 2ms/step
# Loss: nan, Accuracy: 0.9986802935600281

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=25,
        step=2), activation=activation, input_dim=number_input_features))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=25,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# !pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.2.1-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.6/169.6 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (23.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (7.9.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.25.1)
# Requirement already satisfied: tensorflow>=2.0 in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (4.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.21.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.51.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (23.1.21)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.30.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.19.6)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (5.7.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.4.2)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (4.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0->keras-tuner) (0.38.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (0.2.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.12.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.2.2)
# Installing collected packages: kt-legacy, jedi, keras-tuner
# Successfully installed jedi-0.18.2 keras-tuner-1.2.1 kt-legacy-1.0.4

# %%
# Import the kerastuner library
import keras_tuner as kt
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=50,
    hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train,y_train,epochs=20,validation_data=(X_test,y_test))
# Out:
# Trial 180 Complete [00h 01m 08s]
# val_accuracy: 0.9973605871200562
#
# Best val_accuracy So Far: 0.9988452792167664
# Total elapsed time: 00h 51m 30s

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 23,
#  'num_layers': 2,
#  'units_0': 21,
#  'units_1': 23,
#  'units_2': 7,
#  'units_3': 1,
#  'units_4': 19,
#  'units_5': 21,
#  'tuner/epochs': 50,
#  'tuner/initial_epoch': 17,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0068'}

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 190/190 - 0s - loss: nan - accuracy: 0.9988 - 421ms/epoch - 2ms/step
# Loss: nan, Accuracy: 0.9988452792167664
